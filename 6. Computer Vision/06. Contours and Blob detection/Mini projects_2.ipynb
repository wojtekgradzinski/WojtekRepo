# %% [markdown]
# # Mini projects

# %% [markdown]
# ## Level 1

# %% [markdown]
# ### Photo art app

# %% [markdown]
# 1. Create a function that receives an image and converts it to a sketch so it looks similar to this:
# ![Example 1](img/sketch.png)

# %% [markdown]
# ### Instagram filters app

# %% [markdown]
# 1. Create a function that given a photo it applies a black and white filter
# 1. Create a filter that will change color of the image

# %% [markdown]
# ## Level 2

# %% [markdown]
# ### Photo art app

# %% [markdown]
# 1. Change the app so it can now do the same but using your webcam to make it in real time
# **Hint:** you can use ```cv2.VideoCapture(0)```

# %% [markdown]
# ### Photo correction app

# %% [markdown]
# 1. Create a funtion to clean *noise* from images
# ![Noisy image](img/n.png)

# %% [markdown]
# ### Instagram filters app

# %% [markdown]
# 1. Create a function that applies a sepia filter to the image, for a BGR image apply this kernel:
#         [0.272, 0.534, 0.131],
#         [0.349, 0.686, 0.168],
#         [0.393, 0.769, 0.189]
#
# Get the BGR value of the pixel.
# Calculate tr, tg and tb using the formula
#
# tb = 0.272R + 0.534G + 0.131B
# tg = 0.349R + 0.686G + 0.168B
# tr = 0.393R + 0.769G + 0.189B
#
# Take the integer value.
#
# Set the new RGB value of the pixel as per the following condition:
#
# If tb > 255 then b = 255 else b = tb
# If tg > 255 then g = 255 else g = tg
# If tr > 255 then r = 255 else r = tr
#
#
# Example:
#
# Consider a color pixel with the following values
#
# A = 255
#
# R = 100
#
# G = 150
#
# B = 200
#
# Where A, R, G and B represents the Alpha, Red, Green and Blue value of the pixel.
#
# Remember! ARGB will have an integer value in the range 0 to 255.
#
# So, to convert the color pixel into sepia pixel we have to first calculate tr, tg and tb.
#
# tr = 0.393(100) + 0.769(150) + 0.189(200)
#
# tr = 192.45
#
# tr = 192 (taking integer value)
#
# Similarly,
#
# tg = 0.349(100) + 0.686(150) + 0.168(200) = 171 (taking integer value)
#
# and tb = 0.272(100) + 0.534(150) + 0.131(200) = 133 (taking integer value)

# %% [markdown]
# ## Level 3

# %% [markdown]
# ### Instagram filters app

# %% [markdown]
# 1. Apply the sepia filter by using the cv2.transfor function
# 1. Create different filters from the sepia filter so it renders different images

# %% [markdown]
# # More projects

# %% [markdown]
# ## Handwriting recognition

# %% [markdown]
# 1. Write a one digit number (from 0 to 9) on a paper and using your mobile phone take a picture of it
# 1. Crop the image manually and pass it to a a function that will process it so it looks like a char in the MNIST dataset, make sure it is the correct size as well
# ![4](img/4.png)

# %% [markdown]
# 1. Pass it through a MNIST classifier and print the prediction on screen

# %% [markdown]
# 1. Modify the image so now it also contains the predicted result on the image
# 1. Try it with all digits

# %%
import cv2

import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
#read image
path = 'img/numbers/4.png'
img = cv2.imread(path,0)
img.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21772/2761678489.py in <module>
#       2 path = 'img/numbers/4.png'
#       3 img = cv2.imread(path,0)
# ----> 4 img.shape
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
plt.imshow(img, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7780/748931556.py in <module>
# ----> 1 plt.imshow(img, cmap='gray')
#
# ~\anaconda3\envs\cv\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2901         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2902         data=None, **kwargs):
# -> 2903     __ret = gca().imshow(
#    2904         X, cmap=cmap, norm=norm, aspect=aspect,
#    2905         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# ~\anaconda3\envs\cv\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\envs\cv\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5607                               resample=resample, **kwargs)
#    5608
# -> 5609         im.set_data(X)
#    5610         im.set_alpha(alpha)
#    5611         if im.get_clip_path() is None:
#
# ~\anaconda3\envs\cv\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     698         if (self._A.dtype != np.uint8 and
#     699                 not np.can_cast(self._A.dtype, float, "same_kind")):
# --> 700             raise TypeError("Image data of dtype {} cannot be converted to "
#     701                             "float".format(self._A.dtype))
#     702
#
# TypeError: Image data of dtype object cannot be converted to float

# %%
#cropping image

cropped_img = img[1450:2650,1000:1900]
plt.imshow(cropped_img,cmap='gray')

# %%
# treshold application

ret, th = cv2.threshold(cropped_img,100,255,cv2.THRESH_BINARY_INV)
plt.imshow(th, cmap='gray')
print(th.shape)
# Out:
# (1200, 900)

# %%
#resize image

img_resized = cv2.resize(th,(28,28),interpolation= cv2.INTER_AREA)

ret, otsu = cv2.threshold(img_resized, 40, 255,cv2.THRESH_BINARY)
kernel = np.ones((3,3), np.uint8)
dilated_text = cv2.dilate(otsu,kernel, iterations= 1)

plt.imshow(dilated_text, cmap='gray')

cv2.imwrite('test_7.jpg', dilated_text)
# Out:
# True

# %%
from PIL import Image
import joblib
from xgboost import XGBClassifier

# %%
#reshaping img

img = Image.open('test_7.jpg')

plt.imshow(img, cmap='gray')

# %%
img_arr = np.array(img, dtype = int).flatten().reshape(1,784)

# %%
#model application

model = joblib.load('minst_XGboost.sav')


model.predict(img_arr)
# Out:
# array([3], dtype=int64)

# %%
#automated had written numbers prediction prediction
import numpy as np
import joblib
from xgboost import XGBClassifier
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'


def num_prediction(path):
    
    model = joblib.load('minst_XGboost.sav')
    
    img = cv2.imread(path,0) 
    copy = img.copy()
    #cropping
    cnt,
    cropped_img = img[1450:2600,1000:1900]
    tresh = cv2.threshold(cropped_img,100,255,cv2.THRESH_BINARY_INV)
    img_resized = cv2.resize(th,(28,28),interpolation= cv2.INTER_AREA)
    ret, otsu = cv2.threshold(img_resized, 10, 255,cv2.THRESH_BINARY)
    kernel = np.ones((3,3), np.uint8)
    dilated = cv2.dilate(otsu,kernel, iterations= 1)
    plt.imshow(dilated, cmap='gray')
    #prediction
    img_arr = dilated.flatten().reshape(1,784)
    
    return model.predict(img_arr)

# %%
path = 'numbers/8.jpg'

num_prediction(path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2088/4099214870.py in <module>
#       1 path = 'numbers/8.jpg'
#       2
# ----> 3 num_prediction(path)
#
# ~\AppData\Local\Temp/ipykernel_2088/3042691883.py in num_prediction(path)
#      11 def num_prediction(path):
#      12
# ---> 13     model = joblib.load('minst_XGboost.sav')
#      14
#      15     img = cv2.imread(path,0)
#
# ~\anaconda3\envs\cv\lib\site-packages\joblib\numpy_pickle.py in load(filename, mmap_mode)
#     575             obj = _unpickle(fobj)
#     576     else:
# --> 577         with open(filename, 'rb') as f:
#     578             with _read_fileobject(f, filename, mmap_mode) as fobj:
#     579                 if isinstance(fobj, str):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'minst_XGboost.sav'

# %%
path = 'img/numbers/'
plt.figure(figsize=(5,20))
for i in range(3):
    img_read = cv2.imread(path + str(i) + '.jpg',0)
    plt.subplot(1,4,i+1)    
    plt.imshow(img_read, cmap='gray')

# %%
def sort_contours(cnts, method="left-to-right"):
    # initialize the reverse flag and sort index
    reverse = False
    i = 0

    # handle if we need to sort in reverse
    if method == "right-to-left" or method == "bottom-to-top":
        reverse = True

    # handle if we are sorting against the y-coordinate rather than
    # the x-coordinate of the bounding box
    if method == "top-to-bottom" or method == "bottom-to-top":
        i = 1

    # construct the list of bounding boxes and sort them from top to
    # bottom
    boundingBoxes = [cv2.boundingRect(c) for c in cnts]
    (cnts, boundingBoxes) = zip(*sorted(zip(cnts, boundingBoxes),
                                        key=lambda b: b[1][i], reverse=reverse))
    # return the list of sorted contours and bounding boxes
    return (cnts, boundingBoxes)

# %%
img_new = cv2.imread('img/numbers/seven.jpg',0)

blur = cv2.GaussianBlur(img_new,(5,5),0)
canny = cv2.Canny(blur,100,200)

ret ,th = cv2.threshold(canny, 250,255,cv2.THRESH_BINARY)
cnt,h = cv2.findContours(th,cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

coins_copy = img_new.copy()
coins_slovenia = cv2.drawContours(coins_copy, cnt,-1,(0,255,0),3)

plt.figure(figsize = (8,4))
plt.imshow(coins_slovenia, cmap='gray');

# %%
import cv2

# Load image, convert to grayscale, and find edges
image = cv2.imread('img/numbers/eight.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_OTSU + cv2.THRESH_BINARY)[1]

# Find contour and sort by contour area
cnts = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = cnts[0] if len(cnts) == 2 else cnts[1]
cnts = sorted(cnts, key=cv2.contourArea, reverse=True)

# Find bounding box and extract ROI
for c in cnts:
    x,y,w,h = cv2.boundingRect(c)
    ROI = image[y:y+h, x:x+w]
    break

cv2.imshow('ROI',ROI)
cv2.imwrite('ROI.png',ROI)
cv2.waitKey()
# Out:
# -1
