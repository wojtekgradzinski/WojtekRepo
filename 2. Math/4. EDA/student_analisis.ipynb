# %% [markdown]
# # Student Analsis
#
#
# In this notebook I present to you data taken out of a real highschool. In this dataset we have a total of 16 variables and a single class. Most of the data is categorical, this means it is divided into a certain ammount of pre-defined categories. There also a few columns that have numerical data in the form of integers. In this notebook we will try to extract some key features in order to better understand the dataset and as part of the field of 'Data Analysis'.

# %% [markdown]
# ## Step 0:
# ### Load the data into a pandas dataframe
#
# How do you intend to do data analysis without loading the data????
# # ?

# %%
import numpy as np 
import pandas as pd 

df = pd.read_csv("school.csv") 

df
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father           15                16
# 1           IT        F   Father           20                20
# 2           IT        F   Father           10                 7
# 3           IT        F   Father           30                25
# 4           IT        F   Father           40                50
# ..         ...      ...      ...          ...               ...
# 475  Chemistry        S   Father            5                 4
# 476    Geology        F   Father           50                77
# 477    Geology        S   Father           55                74
# 478    History        F   Father           30                17
# 479    History        S   Father           35                14
#
#      AnnouncementsView  Discussion ParentAnsweringSurvey  \
# 0                    2          20                   Yes
# 1                    3          25                   Yes
# 2                    0          30                    No
# 3                    5          35                    No
# 4                   12          50                    No
# ..                 ...         ...                   ...
# 475                  5           8                    No
# 476                 14          28                    No
# 477                 25          29                    No
# 478                 14          57                    No
# 479                 23          62                    No
#
#     ParentschoolSatisfaction StudentAbsenceDays Class
# 0                       Good            Under-7     M
# 1                       Good            Under-7     M
# 2                        Bad            Above-7     L
# 3                        Bad            Above-7     L
# 4                        Bad            Above-7     M
# ..                       ...                ...   ...
# 475                      Bad            Above-7     L
# 476                      Bad            Under-7     M
# 477                      Bad            Under-7     M
# 478                      Bad            Above-7     L
# 479                      Bad            Above-7     L
#
# [480 rows x 17 columns]

# %% [markdown]
# ## Step 1:
# ### Print some elements from the dataset in order to take a quick look at the dataset
#
# Understanding the data you are working with is very important

# %%
# Print 10 e random eldf.headements from the dataset.
df.head(12)
# Out:
#    gender NationalITy PlaceofBirth     StageID GradeID SectionID Topic  \
# 0       M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 1       M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 2       M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 3       M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 4       M          KW       KuwaIT  lowerlevel    G-04         A    IT
# ..    ...         ...          ...         ...     ...       ...   ...
# 95      F          KW       KuwaIT  lowerlevel    G-02         B    IT
# 96      F          KW       KuwaIT  lowerlevel    G-02         C    IT
# 97      F          KW       KuwaIT  lowerlevel    G-02         B    IT
# 98      F          KW       KuwaIT  lowerlevel    G-02         C    IT
# 99      M          KW       KuwaIT  lowerlevel    G-02         B    IT
#
#    Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0         F   Father           15                16                  2
# 1         F   Father           20                20                  3
# 2         F   Father           10                 7                  0
# 3         F   Father           30                25                  5
# 4         F   Father           40                50                 12
# ..      ...      ...          ...               ...                ...
# 95        F   Father          100                80                  2
# 96        F   Father           14                60                 11
# 97        F   Father            6                 2                 38
# 98        F   Father           10                 3                  0
# 99        F   Father           50                 7                  9
#
#     Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# 0           20                   Yes                     Good
# 1           25                   Yes                     Good
# 2           30                    No                      Bad
# 3           35                    No                      Bad
# 4           50                    No                      Bad
# ..         ...                   ...                      ...
# 95          70                    No                      Bad
# 96          75                   Yes                     Good
# 97          12                    No                      Bad
# 98          30                    No                      Bad
# 99          50                   Yes                      Bad
#
#    StudentAbsenceDays Class
# 0             Under-7     M
# 1             Under-7     M
# 2             Above-7     L
# 3             Above-7     L
# 4             Above-7     M
# ..                ...   ...
# 95            Under-7     H
# 96            Under-7     H
# 97            Under-7     M
# 98            Under-7     M
# 99            Above-7     M
#
# [100 rows x 17 columns]

# %% [markdown]
# ## Step 2:
# ### Check for missing or null values
#
# We should always check for missing values as part of getting familiarized with our data.

# %%
# check for null values
print((df.Class=='M').sum())
print((df.Class=='H').sum())
print((df.Class=='L').sum())
# Out:
# 211
# 142
# 127

# %% [markdown]
# ## Step 3:
# ### which is the column with the highest ammount of VARIABILITY?
#
# Time to start extracting info.

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father           15                16
# 1           IT        F   Father           20                20
# 2           IT        F   Father           10                 7
# 3           IT        F   Father           30                25
# 4           IT        F   Father           40                50
# ..         ...      ...      ...          ...               ...
# 475  Chemistry        S   Father            5                 4
# 476    Geology        F   Father           50                77
# 477    Geology        S   Father           55                74
# 478    History        F   Father           30                17
# 479    History        S   Father           35                14
#
#      AnnouncementsView  Discussion ParentAnsweringSurvey  \
# 0                    2          20                   Yes
# 1                    3          25                   Yes
# 2                    0          30                    No
# 3                    5          35                    No
# 4                   12          50                    No
# ..                 ...         ...                   ...
# 475                  5           8                    No
# 476                 14          28                    No
# 477                 25          29                    No
# 478                 14          57                    No
# 479                 23          62                    No
#
#     ParentschoolSatisfaction StudentAbsenceDays Class
# 0                       Good            Under-7     M
# 1                       Good            Under-7     M
# 2                        Bad            Above-7     L
# 3                        Bad            Above-7     L
# 4                        Bad            Above-7     M
# ..                       ...                ...   ...
# 475                      Bad            Above-7     L
# 476                      Bad            Under-7     M
# 477                      Bad            Under-7     M
# 478                      Bad            Above-7     L
# 479                      Bad            Above-7     L
#
# [480 rows x 17 columns]>

# %%
# Check every column EXCEPT the one for the class and find out which one has the highest variability

#sigma = 0
print("\nVarience:\n")
print(np.var(df))
print("\nStandard dev:\n")
print(np.std(df))
# Out:
# Varience:
#
# raisedhands           945.386875
# VisITedResources     1092.007079
# AnnouncementsView     706.682982
# Discussion            762.253056
# dtype: float64
#
# Standard dev:
#
# raisedhands          30.747144
# VisITedResources     33.045530
# AnnouncementsView    26.583510
# Discussion           27.608931
# dtype: float64

# %% [markdown]
# ## Step 4:
# ### Find out for each variable their skewness and plot 5 of them.
#
# Understanding the biases of data can always give us some key information

# %%
df["VisITedResources"].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
# Select 5 columns and find out their bias
df["AnnouncementsView"].hist(bins=50);

# %%
df.hist(column='PlaceofBirth', by= "ParentschoolSatisfaction", bins=25, legend=True, figsize=(12,5), color = 'red', alpha=0.4);

# %%
df.hist(column='Topic', by= "StudentAbsenceDays", bins=25, legend=True, figsize=(12,5), color = 'blue', alpha=0.4);

# %%
df.hist(column='gender', by= "StudentAbsenceDays", bins=25, legend=True, figsize=(12,5), color = 'green', alpha=0.4);

# %%
df.hist(column='raisedhands', by= "Class", bins=25, legend=True, figsize=(12,5), color = 'red', alpha=0.4);

# %%
df.hist(column='ParentschoolSatisfaction', by= "Class", bins=25, legend=True, figsize=(12,5), color = 'blue', alpha=0.4);

# %%
df.hist(column='VisITedResources', by= "Class", bins=25, legend=True, figsize=(12,5), color = 'blue', alpha=0.4);

# %% [markdown]
# ## Step 5:
# ### Find out for all the variables which is their correlation with the class
#
# Sometimes we need to reduce the ammount of features we feed the model in order to make it more lighweight, so we either select the best ones or take out the most useless ones.

# %%
df2 = pd.DataFrame(df, columns = ["Class", "raisedhands", "VisITedResources", "StudentAbsenceDays"] )
df2
# Out:
#     Class  raisedhands  VisITedResources StudentAbsenceDays
# 0       M           15                16            Under-7
# 1       M           20                20            Under-7
# 2       L           10                 7            Above-7
# 3       L           30                25            Above-7
# 4       M           40                50            Above-7
# ..    ...          ...               ...                ...
# 475     L            5                 4            Above-7
# 476     M           50                77            Under-7
# 477     M           55                74            Under-7
# 478     L           30                17            Above-7
# 479     L           35                14            Above-7
#
# [480 rows x 4 columns]

# %%
# Select the top 4 most correlated and put them in a different dataset

# %%
# Select the top 4 least correlated and create a new dataset without them

# %% [markdown]
# ## Step 6:
# ### Visualize the correlation between the previously selected 4 most correlated variables with the class
#
# Lets see if those are correlated too.

# %%
# Plot the correlation among themself for the previous 4 variables.

class_array = np.array(df.raisedhands)
class_array
It_visit_array = np.array(df.VisITedResources)
It_visit_array

pd.DataFrame()

np.correlate(class_array,It_visit_array,mode='valid')
# Out:
# array([1567607], dtype=int64)

# %%
import matplotlib.pyplot as plt



df3 = pd.DataFrame(df, columns = [ "Class", "VisITedResources"] )

plt.matshow(df3.corr())
plt.show()

# %%
import seaborn as sns
corr = df.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Step 7:
# ### For the previoys 4 variables plot them AGAINST the class

# %%
# make 4 plot where you plot each of the variables with the class

# %% [markdown]
# ## Step 8:
# ### Probability time, if I know a student had less than 7 absent days what is the probability of him being classified as L

# %%
# compute the probability
print((df.Class=='M').sum())
print((df.Class=='H').sum())
print((df.Class=='L').sum())
# Out:
# 211
# 142
# 127

# %%
l =(df.Class=='L').sum()
h =(df.Class=='H').sum()
m =(df.Class=='M').sum()

m_percent = m/(h+l)


under_7 = (df.StudentAbsenceDays=='Under-7').sum()
above_7 = (df.StudentAbsenceDays=='Above-7').sum()

df.hist(column='Class', by= "StudentAbsenceDays", bins=25, legend=True, figsize=(12,5), color = 'green', alpha=0.4, ); 

probability = (1/3*l/under_7)
probability
# Out:
# 0.14648212226066895

# %% [markdown]
# ## Step 8:
# ### Probability time, if I know a student had less than 7 absent days what is the probability of him being classified as m or higher, using the previous calculation

# %%
# Looking at step seven extrapolate from it the probability of a student being classified as M or H

# %% [markdown]
# ## Step 9:
# ### Probability time, knowing a student was classified as H, what is the probability of him having raised the hand more than 10 times

# %%
# Bayes time

# %% [markdown]
# ## Step 10:
# ### Free time, if I was the principal of the school what plots and probabilities would you show me to help me accept only M and H students.
