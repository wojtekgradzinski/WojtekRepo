# %%
import pandas as pd

# %%
titanic.to_csv('clean_version_of_titanic.csv', index = False) # ten index powoduje ze nie mamy dodatkowj kolumny z indexami

# %%
titanic = pd.read_csv('clean_version_of_titanic.csv')

# %%
import matplotlib.pyplot as plt

# %%
titanic.plot(subplots = True, figsize = (15,12) , sharex = False, )
plt.show()

# %%
titanic.age.plot( figsize = (18,8), fontsize = 13, c="r",
                xlim = (0,900), ylim = (0,80),xticks = xticks, yticks = yticks,  rot= 45)

plt.title('Titanic - Ages', fontsize = 15)
plt.legend(loc = "best", fontsize = 15)
plt.xlabel("Passanger No" , fontsize = 13)
plt.ylabel("Age", fontsize = 13)
#plt.grid()
plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('classic')

# %%
yticks = [x for x in range(0,81,5)]

# %%
yticks
# Out:
# [0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75, 80]

# %%
xticks = [y for y in range(0,901,50)]

# %%
xticks
# Out:
# [0,
#  50,
#  100,
#  150,
#  200,
#  250,
#  300,
#  350,
#  400,
#  450,
#  500,
#  550,
#  600,
#  650,
#  700,
#  750,
#  800,
#  850,
#  900]

# %%
titanic.age.value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 19.00    25
#          ..
# 55.50     1
# 74.00     1
# 0.92      1
# 70.50     1
# 12.00     1
# Name: age, Length: 88, dtype: int64

# %%
titanic.age.plot(kind= 'hist', figsize= (12,8), bins = 80)
plt.xlabel('Passanger Age')
plt.ylabel('Passanger number')
plt.title('Titanic Data')
plt.grid()
plt.show()
plt.style.use("seaborn-deep")

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
titanic.age.hist(figsize = (12,8), bins = 80, xlabelsize = 12, ylabelsize = 12)
# Out:
# <AxesSubplot:>

# %%
titanic.plot(kind = 'scatter', figsize = (15,8), x ='age' , y='fare',  c= 'survived', marker = 'x' , s = 20, colormap = 'cool')
plt.style.use('seaborn')
plt.show;

"""niebieskie x symbolizuje ludzi ktorzy nie przezylli"""
# Out:
# 'niebieskie x symbolizuje ludzi ktorzy nie przezylli'

# %%
"""SEABORN PLOTTINGS"""

import seaborn as sns

plt.figure(figsize=(12,6))
sns.countplot(data= titanic, x ="sex",hue= 'pclass')
sns.set(font_scale=1,palette='viridis')
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.countplot(data= titanic, y ="sex")
plt.show()

# %%
"""CATEGORICAL PLOTS"""

plt.figure(figsize=(12,6))
sns.stripplot(data= titanic, x ="sex",y = 'age', hue= 'pclass', dodge= True)

plt.style.use('seaborn-deep')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.stripplot(data= titanic, x ="sex",y = 'age', hue= 'survived', dodge= True)

plt.style.use('seaborn-deep')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.swarmplot(data= titanic, x ="sex",y = 'age', hue= 'pclass', dodge= True)

plt.style.use('seaborn-deep')
plt.show();
# Out:
# C:\Users\Wojtek\anaconda3\envs\wojtek\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
"""Regression"""

titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
sns.set(font_scale=1.5)
sns.jointplot(data = titanic, x ='age', y='fare', height =8 , kind ='reg')
plt.show()

# %%
sns.set(font_scale=1.5)
sns.lmplot(data = titanic, x ='age', y='fare', height =8 , hue ='sex')
plt.show()

# %%
sns.set(font_scale=1.5)
sns.lmplot(data = titanic, x ='age', y='fare', height =8 , col ='sex')
plt.show()

# %%
sns.set(font_scale=1.5)
sns.lmplot(data = titanic, x ='age', y='fare', height =8 , row ='sex')
plt.show()

# %%
sns.set(font_scale=1.5)
sns.lmplot(data = titanic, x ='age', y='survived',aspect=1, height =8 , col ='sex', logistic =False)
plt.show()

# %%
sns.set(font_scale=1.5)
sns.lmplot(data = titanic, x ='age', y='survived',aspect=1, height =8 , col =None, logistic =True)
plt.show()

"""Regression slope is down  meaning the older the age of passanger the lower the chances of survival"""

# %%
sns.set(font_scale=1.5)
sns.lmplot(data = titanic, x ='age', y='survived',aspect=1, height =8 , col ='sex', logistic =True)
plt.show()

"""for man the yoiunger the more chances of survival, whereas for woman the opposite is true"""

# %%
sns.set(font_scale=1.5)
sns.lmplot(data = titanic, x ='age', y='survived',aspect=1, height =8 , col ='pclass', logistic =True)
plt.show()

"""all 3 classes present similar data the older the passanger the less chances of survival"""
