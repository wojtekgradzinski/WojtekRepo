# %% [markdown]
# Let's start here.

# %%
import pandas as pd
import seaborn as sns
import IPython
import numpy as np
import sweetviz as sv

# %%
books_df = pd.read_csv("dataset.csv")
books_df.drop('url', axis = 1, inplace=True)
books_df.drop(books_df.columns[0], axis=1, inplace=True)

# %%
books_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  614 non-null    object
#  1   author                 614 non-null    object
#  2   num_reviews            614 non-null    int64
#  3   num_ratings            614 non-null    int64
#  4   avg_rating             614 non-null    float64
#  5   num_pages              614 non-null    int64
#  6   original_publish_year  614 non-null    int64
#  7   series                 614 non-null    bool
#  8   genres                 614 non-null    object
#  9   awards                 614 non-null    object
#  10  places                 314 non-null    object
#  11  awards_count           614 non-null    int64
# dtypes: bool(1), float64(1), int64(5), object(5)
# memory usage: 53.5+ KB

# %%
# books_df.author.nunique(), books_df.shape
books_df.places.isna().sum()
books_df.places.replace(np.nan, "Unknown")
# Out:
# 0       United States
# 1      United Kingdom
# 2      United Kingdom
# 3       United States
# 4             Unknown
#             ...
# 609     United States
# 610     United States
# 611           Unknown
# 612    United Kingdom
# 613           Unknown
# Name: places, Length: 614, dtype: object

# %%
anaylze_report = sv.analyze(books_df)
anaylze_report.show_html('analyze.html', open_browser = True)
# Out:
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:00 -> (00:00 left)
# Report analyze.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
y = books_df['awards_count']
X = books_df

# %%
import matplotlib.pyplot as plt

# %%
books_df.plot()
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
# Out:
#                                  title              author  num_reviews  \
# 537                           Madeline    Ludwig Bemelmans         2022
# 253                    Song of Solomon       Toni Morrison         4216
# 343               Rendezvous with Rama    Arthur C. Clarke         4226
# 347  The Spy Who Came In from the Cold       John le Carré         4926
# 363         The Bridge of San Luis Rey     Thornton Wilder         2128
# ..                                 ...                 ...          ...
# 281                   A Clash of Kings  George R.R. Martin        24353
# 413         The Haunting of Hill House   Shirley Jackson,         16976
# 147                           Catch-22       Joseph Heller        19042
# 233                         The Chosen         Chaim Potok         4305
# 132            The Things They Carried         Tim O'Brien        14865
#
#      num_ratings  avg_rating  num_pages  original_publish_year  series  \
# ...

# %%
compare_report = sv.compare([X_train, 'Train'], [X_test, 'Test'])
compare_report.show_html('compare.html')
# Out:
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:01 -> (00:00 left)Report compare.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-5be31ed7efa5> in <module>
# ----> 1 titanic
#
# NameError: name 'titanic' is not defined
