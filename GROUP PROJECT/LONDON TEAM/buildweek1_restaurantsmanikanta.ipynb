# %%
#import libraries

import requests
import pandas as pd
from bs4 import BeautifulSoup
import re
import matplotlib.pyplot as plt
import random
import time
import numpy as np

# %%
k='&start='
str_="https://www.yelp.co.uk/search?cflt=restaurants&find_loc=london&sortby=recommended{}{}"
names=[]
ratings_=[]
price_ranges=[]
number_of_reviews=[]
type_of_cuisine=[]
for h in range(0,240,10):
    url=str_.format(k,h)
    data = requests.get(url)
    soup=BeautifulSoup(data.content, 'html.parser')
    time.sleep(random.randint(1,5))
    full_data=soup.find_all('div', class_="container__09f24__21w3G hoverable__09f24__2nTf3 margin-t3__09f24__5bM2Z margin-b3__09f24__1DQ9x padding-t3__09f24__-R_5x padding-r3__09f24__1pBFG padding-b3__09f24__1vW6j padding-l3__09f24__1yCJf border--top__09f24__8W8ca border--right__09f24__1u7Gt border--bottom__09f24__xdij8 border--left__09f24__rwKIa border-color--default__09f24__1eOdn")
    for i in full_data:
       
        names.append(i.find('a',class_="css-166la90").get_text())
        number_of_reviews.append(i.find('span',class_='reviewCount__09f24__EUXPN css-e81eai').get_text())
        try:
            type_of_cuisine.append(i.find('a',class_='css-1joxor6').get_text())
        except:
            type_of_cuisine.append(np.nan)
        try:
            m=i.find('span',class_='priceRange__09f24__2O6le css-xtpg8e')
            print(m.get_text())
            price_ranges.append(m.get_text())
        except:
            price_ranges.append(np.nan)
#         try:
#                 a = i.select(".overflow--hidden__09f24__3z7CX")
#                 rating = a[0]["aria-label"]
#                 rating = rating.split(" ")[0]
#                 rating = float(rating)
#                 ratings_.append(rating)
#         except Exception as e:
#                 ratings_.append(np.nan)

        
# ratings_
names
# Out:
# ££
# ££
# ££
# ££
# ££
# ££
# ££££
# ££
# £££
# ££
# ££
# £££
# £££
# ££
# £
# ££
# £
# £££
# £££
# ££
# £££
# ££
# £££
# ££
# ££
# ££
# ££
# £
# ££
# £
# ££££
# ££
# £££
# ££
# ££
# ££
# ££
# £££
# ££
# ££
# ££
# ££
# ££
# ££
# £££
# ££
# ££
# ££
# ££
# £££
# ££
# £
# £££
# ££
# £££
# ££
# ££
# £££
# £
# £££
# ££
# £
# £
# ££
# ££
# ££
# £££
# ££
# ££££
# ££££
# ££
# £
# £££
# ££
# ££
# ££
# ££
# ££
# £££
# £££
# £££
# £££
# £
# £££
# £
# ££
# ££
# £
# ££
# ££
# £
# ££
# £££
# ££
# £££
# ££
# ££
# ££
# ££
# ££
# ££
# £
# ££
# ££
# ££
# £££
# £££
# £
# £££
# £££
# ££
# £
# £
# £££
# ££
# £
# £££
# £££
# £
# £££
# £
# £
# ££
# £££
# £££
# ££
# ££££
# ££
# ££
# £
# ££
# £££
# ££
# £
# £
# £££
# ££
# ££
# ££
# £££
# ££
# ££
# £££
# ££
# ££
# ££
# £
# ££
# ££
# £££
# ££
# ££
# ££
# ££
# ££
# ££
# ££
# ££
# ££
# ££
# £££
# ££
# £
# ££
# £££
# £££
# £££
# ££
# ££
# £
# ££
# £££
# ££
# ££
# ££
# £
# £££
# £
# ££
# ££
# ££
# ££
# £
# ££££
# ££
# £££
# ££
# ££
# ££
# ££
# ££
# £££
# ££
# ££
# ...

# %%
len(price_ranges)
# Out:
# 240

# %%
df = pd.DataFrame ({'Name of restaurant' : names, 'NUmber of Reviews': number_of_reviews,'Price range' : price_ranges,'Type of cuisine': type_of_cuisine,'Ratings': ratings})

df.to_excel('LondonRestaurants.xlsx', engine='xlsxwriter')
df
# Out:
#                 Name of restaurant NUmber of Reviews Price range  \
# 0               The Mayfair Chippy               281          ££
# 1                          Dishoom              1845          ££
# 2               The Breakfast Club               495          ££
# 3                        Flat Iron               379          ££
# 4                     The Fat Bear               122          ££
# ..                             ...               ...         ...
# 235            Kintan Japanese BBQ                51          ££
# 236  Bernardi’s Restaurant and Bar                31         £££
# 237                  Honey & Smoke                 7          ££
# 238                           José                82          ££
# 239                         Bill’s               207          ££
#
#             Type of cuisine Ratings
# 0              Fish & Chips     4.5
# 1                    Indian     4.5
# 2        Coffee & Tea Shops       4
# 3               Steakhouses     4.5
# ...

# %%
# Out:
# British                   26
# Italian                   18
# Japanese                  11
# Cafes                      9
# Chinese                    8
# Modern European            7
# Coffee & Tea Shops         7
# French                     7
# Mexican                    6
# Fish & Chips               6
# Tapas & Small Plates       5
# American (Traditional)     5
# Middle Eastern             5
# Thai                       5
# Indian                     5
# Bars                       4
# Pubs                       4
# Malaysian                  4
# Steakhouses                4
# Seafood                    4
# Pizza                      3
# Chicken Shop               3
# Noodles                    3
# Burgers                    3
# Vietnamese                 3
# Breakfast & Brunch         3
# Spanish                    3
# Lebanese                   2
# Taiwanese                  2
# Sandwiches                 2
# Greek                      2
# Dim Sum                    2
# ...

# %%
ratings=[]
for h in range(0,240,10):
    url=str_.format(k,h)
    data = requests.get(url)
    soup=BeautifulSoup(data.content, 'html.parser')
    time.sleep(random.randint(1,5))
    full_data=soup.find_all('div', class_="container__09f24__21w3G hoverable__09f24__2nTf3 margin-t3__09f24__5bM2Z margin-b3__09f24__1DQ9x padding-t3__09f24__-R_5x padding-r3__09f24__1pBFG padding-b3__09f24__1vW6j padding-l3__09f24__1yCJf border--top__09f24__8W8ca border--right__09f24__1u7Gt border--bottom__09f24__xdij8 border--left__09f24__rwKIa border-color--default__09f24__1eOdn")
    for i in full_data:          
            try:
                a = i.select(".overflow--hidden__09f24__3z7CX")
                rat = a[0]["aria-label"]
                rat = rat.split(" ")
                               
                ratings.append(rat[0])
            except:
                ratings.append(np.nan)
            
ratings
# Out:
# ['4.5',
#  '4.5',
#  '4',
#  '4.5',
#  '4.5',
#  '4.5',
#  '4.5',
#  '4',
#  '4.5',
#  '4.5',
#  '4.5',
#  '4',
#  '4',
#  '4.5',
#  '4.5',
#  '4.5',
#  '4',
#  '4.5',
#  '4',
#  '4',
#  '4.5',
#  '4.5',
#  '5',
#  '4.5',
#  '4',
#  '4.5',
#  '4.5',
#  '4.5',
#  '4',
#  '4',
#  '4',
#  '5',
#  '4',
#  '4.5',
#  '4.5',
#  '4.5',
#  '4',
#  '4',
#  '4.5',
#  '4.5',
#  '4.5',
#  '4',
#  '4.5',
#  '4',
#  '4',
#  '4.5',
#  '4.5',
#  '4.5',
#  '4',
#  '4.5',
#  '4',
#  '4.5',
#  '4',
#  '5',
#  '4',
#  '4',
#  '4.5',
#  '4',
#  '4.5',
#  '5',
#  '4',
#  '4.5',
#  '4.5',
#  '4',
#  '4',
#  '4.5',
#  '4',
#  '4',
#  '4.5',
#  '4.5',
#  '4.5',
#  '4',
#  '4.5',
#  '4.5',
#  '4',
#  '4.5',
#  '4',
#  '4.5',
#  '4.5',
#  '4.5',
#  '4',
#  '4',
#  '4.5',
#  '4.5',
#  '4.5',
#  '4',
#  '4.5',
#  '4',
#  '4',
#  '5',
#  '4.5',
#  '4.5',
#  '5',
#  '4.5',
#  '4.5',
#  '4',
#  '4.5',
#  '4.5',
#  '4',
#  '4.5',
#  '4',
#  '4.5',
#  '4.5',
#  '4',
#  '4',
#  '4',
#  '4.5',
#  '4.5',
#  '5',
#  '4',
# ...

# %%
#df.letters.value_counts().sort_values().plot(kind = 'barh')
df['Type of cuisine'].value_counts().sort_values().plot(kind = 'barh')
# Out:
# <AxesSubplot:>
