# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import bs4
from time import sleep
import time
import random
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('LondonPubs.xlsx')
df.describe()
# Out:
#        Pubs_reviews  Pubs_ratings
# count    230.000000    230.000000
# mean      54.395652      4.058696
# std       76.772931      0.422912
# min        1.000000      3.000000
# 25%       15.000000      4.000000
# 50%       31.000000      4.000000
# 75%       63.750000      4.500000
# max      705.000000      5.000000

# %%
df_1 = pd.read_excel('LondonRestaurants.xlsx')

# %%
df_1.drop(df_1.columns[0], axis=1, inplace=True)

# %%
#df_1.drop(df.columns[0], axis=1, inplace=True)

# %%
plt.figure(figsize=(12,6))
sns.swarmplot(data= df_1, x ="Type_of_cuisine",y = 'Number_of_Reviews', hue= 'Price_range')
plt.title('Pubs-London')
plt.style.use('seaborn-deep')
plt.show();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d07741f0cb2d> in <module>
# ----> 1 plt.figure(figsize=(12,6))
#       2 sns.swarmplot(data= df_1, x ="Type_of_cuisine",y = 'Number_of_Reviews', hue= 'Price_range')
#       3 plt.title('Pubs-London')
#       4 plt.style.use('seaborn-deep')
#       5 plt.show();
#
# NameError: name 'plt' is not defined

# %%
 
df_1
# Out:
#                 Name_of_restaurant  Number_of_Reviews Price_range  \
# 0               The Mayfair Chippy                281          ££
# 1                          Dishoom               1845          ££
# 2               The Breakfast Club                495          ££
# 3                        Flat Iron                379          ££
# 4                     The Fat Bear                122          ££
# ..                             ...                ...         ...
# 235            Kintan Japanese BBQ                 51          ££
# 236  Bernardi’s Restaurant and Bar                 31         £££
# 237                  Honey & Smoke                  7          ££
# 238                           José                 82          ££
# 239                         Bill’s                207          ££
#
#             Type_of_cuisine  Ratings
# 0              Fish & Chips      4.5
# 1                    Indian      4.5
# 2        Coffee & Tea Shops      4.0
# ...

# %%
df
# Out:
#                Pubs_names  Pubs_reviews  Pubs_ratings Pubs_price_range  \
# 0                The Harp           135           4.5                £
# 1             Cahoots Bar           106           4.5               ££
# 2       The Monkey Puzzle            53           4.5               ££
# 3              The Crobar            43           4.5                £
# 4        The Queen’s Head            47           4.0               ££
# ..                    ...           ...           ...              ...
# 225   St Christophers Inn            44           3.5               ££
# 226        Piebury Corner            35           5.0                £
# 227  The Warrington Hotel            71           3.5               ££
# 228   The Edinboro Castle            68           3.5               ££
# 229               Parlour            20           4.0              £££
#
#                                            pub_reviews
# 0    “One of my favorite  pubs  in London. It was a...
# ...

# %%
df.to_excel('LondonPubs_clean.xlsx', engine='xlsxwriter',index=False )

# %%
import seaborn as sns

plt.figure(figsize=(8,4))
sns.countplot(data= df, x ="Pubs_ratings",hue= 'Pubs_price_range')
sns.set(font_scale=1,palette='viridis')
plt.title('Pubs-London', fontsize = 15)
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.countplot(data= df_1, x ="Ratings",hue= 'Price_range')
sns.set(font_scale=1,palette='viridis')
plt.title('Restaurants-London', fontsize = 15)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(data= df_2, x ="H_Ratings",hue= 'H_Price_Range')
sns.set(font_scale=1,palette='viridis')
plt.title('Hotels-London', fontsize = 15)
plt.show()
# Out:
# C:\Users\Wojtek\anaconda3\envs\wojtek\lib\site-packages\matplotlib\textpath.py:74: RuntimeWarning: Glyph 65533 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\Users\Wojtek\anaconda3\envs\wojtek\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 65533 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Wojtek\anaconda3\envs\wojtek\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 65533 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
sns.set(font_scale=1)
sns.jointplot(data = df, x ='Pubs_ratings', y='Pubs_reviews', height =8 , kind ='reg')
plt.title('Pubs-London', fontsize = 10)
plt.show()

# %%
sns.set(font_scale=1)
sns.jointplot(data = df_1, x ='Ratings', y='Number_of_Reviews', height =6 , kind ='reg')
plt.title('Restaurants-London', fontsize = 10)
plt.show()

# %%
sns.set(font_scale=1.5)
sns.jointplot(data = df_2, x ='H_Ratings', y='Hotel_Reviews', height =8 , kind ='reg')
plt.title('Hotels-London', fontsize = 15)
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.swarmplot(data= df, x ="Pubs_ratings",y = 'Pubs_reviews', hue= 'Pubs_price_range')
plt.title('Pubs-London')
plt.style.use('seaborn-deep')
plt.show();
# Out:
# C:\Users\Wojtek\anaconda3\envs\wojtek\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Wojtek\anaconda3\envs\wojtek\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 28.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Wojtek\anaconda3\envs\wojtek\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 34.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(8,4))
sns.swarmplot(data= df_1, x ="Ratings",y = 'Number_of_Reviews', hue= 'Price_range')
plt.title('Restaurants-London')
plt.style.use('seaborn-deep')
plt.show();
# Out:
# C:\Users\Wojtek\anaconda3\envs\wojtek\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 16.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Wojtek\anaconda3\envs\wojtek\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(8,4))
sns.swarmplot(data= df_2, x ="H_Ratings",y = 'Hotel_Reviews', hue= 'H_Price_Range')
plt.title('Hotels-London')
plt.style.use('seaborn-deep')
plt.show();
# Out:
# C:\Users\Wojtek\anaconda3\envs\wojtek\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 26.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Wojtek\anaconda3\envs\wojtek\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Wojtek\anaconda3\envs\wojtek\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 61.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(5,5))
sns.set(font_scale=1)
plt.title('Pubs-London')
sns.heatmap(pd.crosstab(df.Pubs_ratings, df.Pubs_price_range), annot=True, fmt = 'd', cmap='Reds', vmax = 50)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.set(font_scale=1)
plt.title('Restaurants-London')
sns.heatmap(pd.crosstab(df_1.Ratings, df_1.Price_range), annot=True, fmt = 'd', cmap='Reds', vmax = 50)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.set(font_scale=1)
plt.title('Hotels-London')
sns.heatmap(pd.crosstab(df_2.H_Ratings, df_2.H_Price_Range), annot=True, fmt = 'd', cmap='Reds', vmax = 25)
plt.show()

# %%
df
# Out:
#                Pubs_names  Pubs_reviews  Pubs_ratings Pubs_price_range  \
# 0                The Harp           135           4.5                £
# 1             Cahoots Bar           106           4.5               ££
# 2       The Monkey Puzzle            53           4.5               ££
# 3              The Crobar            43           4.5                £
# 4        The Queen’s Head            47           4.0               ££
# ..                    ...           ...           ...              ...
# 225   St Christophers Inn            44           3.5               ££
# 226        Piebury Corner            35           5.0                £
# 227  The Warrington Hotel            71           3.5               ££
# 228   The Edinboro Castle            68           3.5               ££
# 229               Parlour            20           4.0              £££
#
#                                            pub_reviews
# 0    “One of my favorite  pubs  in London. It was a...
# ...

# %%
df
# Out:
#                Pubs_names  Pubs_reviews  Pubs_ratings Pubs_price_range  \
# 0                The Harp           135           4.5                £
# 1             Cahoots Bar           106           4.5               ££
# 2       The Monkey Puzzle            53           4.5               ££
# 3              The Crobar            43           4.5                £
# 4        The Queen’s Head            47           4.0               ££
# ..                    ...           ...           ...              ...
# 225   St Christophers Inn            44           3.5               ££
# 226        Piebury Corner            35           5.0                £
# 227  The Warrington Hotel            71           3.5               ££
# 228   The Edinboro Castle            68           3.5               ££
# 229               Parlour            20           4.0              £££
#
#                                            pub_reviews
# 0    “One of my favorite  pubs  in London. It was a...
# ...

# %%
df['Pubs_price_range'].value_counts()
# Out:
# ££      188
# £        30
# £££      10
# ££££      2
# Name: Pubs_price_range, dtype: int64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
f_sum = 30
ff_sum= 188
fff_sum= 10
ffff_sum= 2
Total_f= np.array([30,188,10,2]).sum()

f_prbability = f_sum/Total_f
ff_prbability= ff_sum/Total_f
fff_prbability= fff_sum/Total_f
ffff_prbability= ffff_sum/Total_f

price_ranges = np.array([f_prbability,ff_prbability,fff_prbability,ffff_prbability]).round(2)*100 
labels = ["£", "££", "£££","££££"]
myexplode = [0.1,0,0,0]
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
plt.pie(price_ranges, labels=labels,colors=colors, explode = myexplode, autopct='%1.1f%%', shadow=True)
plt.title("Probability of Choosing a Pub by its Price Range")

plt.show()


df_price_ranges = pd.DataFrame(price_ranges, index=  ["£", "££", "£££","££££"])
df_price_ranges[0] = df_price_ranges[0].apply(lambda x: str(x) + "%")
print(df_price_ranges)
# Out:
#           0
# £     13.0%
# ££    82.0%
# £££    4.0%
# ££££   1.0%

# %%
df_1['Price_range'].value_counts()
# Out:
# ££      112
# £££      47
# £        30
# ££££      6
# Name: Price_range, dtype: int64

# %%
f_sum = 30
ff_sum= 112
fff_sum= 47
ffff_sum= 6
Total_f= np.array([30,112,47,6]).sum()

f_prbability = f_sum/Total_f
ff_prbability= ff_sum/Total_f
fff_prbability= fff_sum/Total_f
ffff_prbability= ffff_sum/Total_f

price_ranges = np.array([f_prbability,ff_prbability,fff_prbability,ffff_prbability]).round(2)*100 
labels = ["£", "££", "£££","££££"]
myexplode = [0.1,0,0,0]

colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
plt.pie(price_ranges, labels=labels,colors=colors, explode = myexplode, autopct='%1.1f%%', shadow=True)
plt.title("Probability of Choosing a Restaurant by its Price Range")
plt.show()


df_price_ranges = pd.DataFrame(price_ranges, index=  ["£", "££", "£££","££££"])
df_price_ranges[0] = df_price_ranges[0].apply(lambda x: str(x) + "%")
print(df_price_ranges)
# Out:
#                        0
# £                  15.0%
# ££    56.99999999999999%
# £££                24.0%
# ££££                3.0%

# %%
df_2 = pd.read_csv('londonhotel.csv')

# %%
df
# Out:
#                  Address  Values
# 0                   Soho      38
# 1              Fitzrovia      19
# 2          Covent_Garden      14
# 3                Mayfair      13
# 4             Bloomsbury      11
# 5             Marylebone      11
# 6            Westminster      11
# 7               Victoria       7
# 8                Chelsea       7
# 9   Strand_Covent_Garden       7
# 10               Pimlico       6
# 11            Paddington       5

# %%
df.Values.hist(figsize = (12,8), bins = 20, xlabelsize = 12, ylabelsize = 12)
# Out:
# <AxesSubplot:>

# %%
p = plt.hist(df)
plt.xticks(rotation='vertical')
plt.bins = 5
plt.show()

# %%
df.Address.plot(kind= 'hist', figsize= (12,8), bins = 12)
plt.xlabel('Address')
plt.ylabel('Values')
plt.title('Number of Restaurants in London Area')
plt.xticks(rotation='vertical')
plt.grid()
plt.show()
plt.style.use("seaborn-deep")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-507-16755ce4cbf5> in <module>
# ----> 1 df.Address.plot(kind= 'hist', figsize= (12,8), bins = 12)
#       2 plt.xlabel('Address')
#       3 plt.ylabel('Values')
#       4 plt.title('Number of Restaurants in London Area')
#       5 plt.xticks(rotation='vertical')
#
# ~\anaconda3\envs\wojtek\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     953                     data.columns = label_name
#     954
# --> 955         return plot_backend.plot(data, kind=kind, **kwargs)
#     956
#     957     __call__.__doc__ = __doc__
#
# ~\anaconda3\envs\wojtek\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ...

# %%
df_rest = pd.read_excel('RestaurantsA.xlsx')
df_rest
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-457-1c364629573c> in <module>
#       1 df_rest = pd.read_excel('RestaurantsA.xlsx')
#       2 df_rest
# ----> 3 df_rest.addresses.hist(figsize = (12,8), bins = 80, xlabelsize = 12, ylabelsize = 12)
#
# ~\anaconda3\envs\wojtek\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'addresses'

# %%
df.to_excel('restaurant_dictionary.xlsx', engine='xlsxwriter', index=False)

# %%
df_3 = pd.read_excel('LondonRestaurants.xlsx')
df_3
# Out:
#      Unnamed: 0             Name_of_restaurant  Number_of_Reviews Price_range  \
# 0             0             The Mayfair Chippy                281          ££
# 1             1                        Dishoom               1845          ££
# 2             2             The Breakfast Club                495          ££
# 3             3                      Flat Iron                379          ££
# 4             4                   The Fat Bear                122          ££
# ..          ...                            ...                ...         ...
# 235         235            Kintan Japanese BBQ                 51          ££
# 236         236  Bernardi’s Restaurant and Bar                 31         £££
# 237         237                  Honey & Smoke                  7          ££
# 238         238                           José                 82          ££
# 239         239                         Bill’s                207          ££
#
# ...

# %%
df_3['Adresses'].value_counts()
# Out:
# Soho                                         38
# Fitzrovia                                    19
# Covent Garden                                14
# Mayfair                                      13
# Bloomsbury                                   11
# Marylebone                                   11
# Westminster                                  11
# Victoria                                      7
# Chelsea                                       7
# Strand, Covent Garden                         7
# Pimlico                                       6
# Paddington                                    5
# Covent Garden, Strand                         5
# Kensington                                    5
# Notting Hill                                  5
# Clerkenwell                                   4
# Euston                                        4
# Spitalfields                                  4
# The City                                      4
# Chinatown                                     3
# ...

# %%
#df_1['Price_range'].value_counts()
#df_1_completed = df_1.append(df_3, igonre index)

dict_rest ={'Address':['Soho','Fitzrovia','Covent_Garden','Mayfair','Bloomsbury','Marylebone','Westminster','Victoria','Chelsea',                       'Strand_Covent_Garden','Pimlico','Paddington'],
            'Values':[38,19, 14 , 13 ,11,11,11,7,7,7,6,5]}

# %%
df = pd.DataFrame(dict_rest)
df
# Out:
#                  Address  Values
# 0                   Soho      38
# 1              Fitzrovia      19
# 2          Covent_Garden      14
# 3                Mayfair      13
# 4             Bloomsbury      11
# 5             Marylebone      11
# 6            Westminster      11
# 7               Victoria       7
# 8                Chelsea       7
# 9   Strand_Covent_Garden       7
# 10               Pimlico       6
# 11            Paddington       5

# %%
df_1_completed
# Out:
#      Name_of_restaurant  Number_of_Reviews Price_range  \
# 0    The Mayfair Chippy              281.0          ££
# 1               Dishoom             1845.0          ££
# 2    The Breakfast Club              495.0          ££
# 3             Flat Iron              379.0          ££
# 4          The Fat Bear              122.0          ££
# ..                  ...                ...         ...
# 191                 NaN                NaN         NaN
# 192                 NaN                NaN         NaN
# 193                 NaN                NaN         NaN
# 194                 NaN                NaN         NaN
# 195                 NaN                NaN         NaN
#
#             Type_of_cuisine  Ratings       Adresses
# 0              Fish & Chips      4.5            NaN
# 1                    Indian      4.5            NaN
# 2        Coffee & Tea Shops      4.0            NaN
# 3               Steakhouses      4.5            NaN
# ...

# %%
df_2
# Out:
#                            Hotel_Name  Hotel_Reviews H_Price_Range  H_Ratings
# 0             The Hoxton - Shoreditch          187.0            ��        4.5
# 1                        Ruskin Hotel            1.0            ��        5.0
# 2                The Kensington Hotel           45.0           ���        4.5
# 3                            Hotel 41           29.0          ����        5.0
# 4                        Holiday Inn            22.0            ��        3.5
# ..                                ...            ...           ...        ...
# 235                     Palmers Lodge           35.0            ��        4.0
# 236              Travelodge Battersea            1.0            ��        4.0
# 237                Citadines Barbican            5.0            ��        3.0
# 238                       Qbic Hotel            19.0            ��        4.0
# 239  High Holborn Hall - Early Summer            1.0            ��        5.0
#
# [240 rows x 4 columns]

# %%
df_2
# Out:
#                            Hotel_Name  Hotel_Reviews H_Price_Range  H_Ratings
# 0             The Hoxton - Shoreditch          187.0           ££         4.5
# 1                        Ruskin Hotel            1.0           ££         5.0
# 2                The Kensington Hotel           45.0          £££         4.5
# 3                            Hotel 41           29.0         ££££         5.0
# 4                        Holiday Inn            22.0           ££         3.5
# ..                                ...            ...           ...        ...
# 235                     Palmers Lodge           35.0           ££         4.0
# 236              Travelodge Battersea            1.0           ££         4.0
# 237                Citadines Barbican            5.0           ££         3.0
# 238                       Qbic Hotel            19.0           ££         4.0
# 239  High Holborn Hall - Early Summer            1.0           ££         5.0
#
# [240 rows x 4 columns]

# %%
df_2['H_Price_Range'].value_counts()
# Out:
# ££       118
# £££       87
# £         21
# ££££      14
# Name: H_Price_Range, dtype: int64

# %%
f_sum = 21
ff_sum= 118
fff_sum= 87
ffff_sum= 14
Total_f= np.array([30,112,47,6]).sum()

f_prbability = f_sum/Total_f
ff_prbability= ff_sum/Total_f
fff_prbability= fff_sum/Total_f
ffff_prbability= ffff_sum/Total_f

price_ranges = np.array([f_prbability,ff_prbability,fff_prbability,ffff_prbability]).round(2)*100 
labels = ["£", "££", "£££","££££"]
myexplode = [0.1,0,0,0]

colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
plt.pie(price_ranges, labels=labels,colors=colors, explode = myexplode, autopct='%1.1f%%', shadow=True)
plt.title("Probability of Choosing a Hotel by its Price Range")
plt.show()


df_price_ranges = pd.DataFrame(price_ranges, index=  ["£", "££", "£££","££££"])
df_price_ranges[0] = df_price_ranges[0].apply(lambda x: str(x) + "%")
print(df_price_ranges)
# Out:
#                        0
# £                  11.0%
# ££                 61.0%
# £££                45.0%
# ££££  7.000000000000001%
