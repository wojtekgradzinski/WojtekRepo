# %%
import numpy as np
import cv2
import os
from tqdm import tqdm
import random
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.patches as patches
import pickle
from glob import glob 
import imgaug as ia
from imgaug import augmenters as iaa
from shapely.geometry import Polygon

# %%
cardW=57
cardH=87
cornerXmin=2
cornerXmax=10.5
cornerYmin=2.5
cornerYmax=23

# We convert the measures from mm to pixels: multiply by an arbitrary factor 'zoom'
# You shouldn't need to change this
zoom=4
cardW*=zoom
cardH*=zoom
cornerXmin=int(cornerXmin*zoom)
cornerXmax=int(cornerXmax*zoom)
cornerYmin=int(cornerYmin*zoom)
cornerYmax=int(cornerYmax*zoom)

# %%
def display_img(img,polygons=[],channels="bgr",size=9):
    """
        Function to display an inline image, and draw optional polygons (bounding boxes, convex hulls) on it.
        Use the param 'channels' to specify the order of the channels ("bgr" for an image coming from OpenCV world)
    """
    if not isinstance(polygons,list):
        polygons=[polygons]    
    if channels=="bgr": # bgr (cv2 image)
        nb_channels=img.shape[2]
        if nb_channels==4:
            img=cv2.cvtColor(img,cv2.COLOR_BGRA2RGBA)
        else:
            img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)    
    fig,ax=plt.subplots(figsize=(size,size))
    ax.set_facecolor((0,0,0))
    ax.imshow(img)
    for polygon in polygons:
        # An polygon has either shape (n,2), 
        # either (n,1,2) if it is a cv2 contour (like convex hull).
        # In the latter case, reshape in (n,2)
        if len(polygon.shape)==3:
            polygon=polygon.reshape(-1,2)
        patch=patches.Polygon(polygon,linewidth=1,edgecolor='g',facecolor='none')
        ax.add_patch(patch)

# %%
img = cv2.imread('data/cards/cards-[C0]-001.jpg')
display_img(img)

# %%
data_dir="data" # Directory that will contain all kinds of data (the data we download and the data we generate)

if not os.path.isdir(data_dir):
    os.makedirs(data_dir)

card_suits=['s','h','d','c']
card_values=['A','K','Q','J','10','9','8','7','6','5','4','3','2']

# Pickle file containing the background images from the DTD
backgrounds_pck_fn=data_dir+"/backgrounds.pck"

# Pickle file containing the card images
cards_pck_fn=data_dir+"/cards.pck"


# imgW,imgH: dimensions of the generated dataset images 
imgW=720
imgH=720

# %%
import gzip
with gzip.open('dtd-r1.0.1.tar.gz', 'rb') as f:
    file_content = f.read()

# %%
#Extract the DTD 
# !tar xf dtd-r1.0.1.tar.gz
# Out:
# ^C

# %%
from glob import glob 
dtd_dir="dtd/images/"
bg_images=[]
for subdir in glob(dtd_dir+"/*"):
    for f in glob(subdir+"/*.jpg"):
        bg_images.append(mpimg.imread(f))
print("Nb of images loaded :",len(bg_images))
print("Saved in :",backgrounds_pck_fn)
pickle.dump(bg_images,open(backgrounds_pck_fn,'wb'))
# Out:
# Nb of images loaded : 5640
# Saved in : data/backgrounds.pck

# %%
class Backgrounds():
    def __init__(self,backgrounds_pck_fn=backgrounds_pck_fn):
        self._images=pickle.load(open(backgrounds_pck_fn,'rb'))
        self._nb_images=len(self._images)
        print("Nb of images loaded :", self._nb_images)
    def get_random(self, display=False):
        bg=self._images[random.randint(0,self._nb_images-1)]
        if display: plt.imshow(bg)
        return bg
    
backgrounds = Backgrounds()
# Out:
# Nb of images loaded : 5640

# %%
# Test: display a random background
_=backgrounds.get_random(display=True)

# %%
bord_size=2 # bord_size alpha=0
alphamask=np.ones((cardH,cardW),dtype=np.uint8)*255
cv2.rectangle(alphamask,(0,0),(cardW-1,cardH-1),0,bord_size)
cv2.line(alphamask,(bord_size*3,0),(0,bord_size*3),0,bord_size)
cv2.line(alphamask,(cardW-bord_size*3,0),(cardW,bord_size*3),0,bord_size)
cv2.line(alphamask,(0,cardH-bord_size*3),(bord_size*3,cardH),0,bord_size)
cv2.line(alphamask,(cardW-bord_size*3,cardH),(cardW,cardH-bord_size*3),0,bord_size)
plt.figure(figsize=(10,10))
plt.imshow(alphamask)

# %%
def varianceOfLaplacian(img):
    """
    Compute the Laplacian of the image and then return the focus
    measure, which is simply the variance of the Laplacian
    Source: A.Rosebrock, https://www.pyimagesearch.com/2015/09/07/blur-detection-with-opencv/
    """
    return cv2.Laplacian(img, cv2.CV_64F).var()

def extract_card (img, output_fn=None, min_focus=120, debug=False):
    """
    """
    
    imgwarp=None
    
    # Check the image is not too blurry
    focus=varianceOfLaplacian(img)
    if focus < min_focus: 
        if debug: print("Focus too low :", focus)
        return False,None
    
    # Convert in gray color
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    
    # Noise-reducing and edge-preserving filter
    gray=cv2.bilateralFilter(gray,11,17,17)
    
    # Edge extraction
    edge=cv2.Canny(gray,30,200)
    
    # Find the contours in the edged image
    _,cnts, _ = cv2.findContours(edge.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # We suppose that the contour with largest area corresponds to the contour delimiting the card
    cnt = sorted(cnts, key = cv2.contourArea, reverse = True)[0]
    
    # We want to check that 'cnt' is the contour of a rectangular shape
    # First, determine 'box', the minimum area bounding rectangle of 'cnt'
    # Then compare area of 'cnt' and area of 'box'
    # Both areas sould be very close
    rect=cv2.minAreaRect(cnt)
    box=cv2.boxPoints(rect)
    box=np.int0(box)
    areaCnt=cv2.contourArea(cnt)
    areaBox=cv2.contourArea(box)
    valid=areaCnt/areaBox>0.95
    
    if valid:
        # We want transform the zone inside the contour into the reference rectangle of dimensions (cardW,cardH)
        ((xr,yr),(wr,hr),thetar)=rect
        # Determine 'Mp' the transformation that transforms 'box' into the reference rectangle
        if wr>hr:
            Mp=cv2.getPerspectiveTransform(np.float32(box),refCard)
        else:
            Mp=cv2.getPerspectiveTransform(np.float32(box),refCardRot)
        # Determine the warped image by applying the transformation to the image
        imgwarp=cv2.warpPerspective(img,Mp,(cardW,cardH))
        # Add alpha layer
        imgwarp=cv2.cvtColor(imgwarp,cv2.COLOR_BGR2BGRA)
        
        # Shape of 'cnt' is (n,1,2), type=int with n = number of points
        # We reshape into (1,n,2), type=float32, before feeding to perspectiveTransform
        cnta=cnt.reshape(1,-1,2).astype(np.float32)
        # Apply the transformation 'Mp' to the contour
        cntwarp=cv2.perspectiveTransform(cnta,Mp)
        cntwarp=cntwarp.astype(np.int)
        
        # We build the alpha channel so that we have transparency on the
        # external border of the card
        # First, initialize alpha channel fully transparent
        alphachannel=np.zeros(imgwarp.shape[:2],dtype=np.uint8)
        # Then fill in the contour to make opaque this zone of the card 
        cv2.drawContours(alphachannel,cntwarp,0,255,-1)
        
        # Apply the alphamask onto the alpha channel to clean it
        alphachannel=cv2.bitwise_and(alphachannel,alphamask)
        
        # Add the alphachannel to the warped image
        imgwarp[:,:,3]=alphachannel
        
        # Save the image to file
        if output_fn is not None:
            cv2.imwrite(output_fn,imgwarp)
        
    if debug:
        cv2.imshow("Gray",gray)
        cv2.imshow("Canny",edge)
        edge_bgr=cv2.cvtColor(edge,cv2.COLOR_GRAY2BGR)
        cv2.drawContours(edge_bgr,[box],0,(0,0,255),3)
        cv2.drawContours(edge_bgr,[cnt],0,(0,255,0),-1)
        cv2.imshow("Contour with biggest area",edge_bgr)
        if valid:
            cv2.imshow("Alphachannel",alphachannel)
            cv2.imshow("Extracted card",imgwarp)

    return valid,imgwarp

# %%
# Test on one image
debug=False
img=cv2.imread("data/cards/cards-[C0]-001.jpg")
display_img(img)
valid,card=extract_card(img,"extracted_card.jpg", debug=debug)
if valid:
    display_img(card)
if debug:
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
display_img(img)

# %%
from glob import glob 
dtd_dir="Cards/train/images/"
bg_images=[]
for f in glob(dtd_dir+"/*.jpg"):
    
    bg_images.append(f)
print("Nb of images loaded :",len(bg_images))
# Out:
# Nb of images loaded : 208

# %%
bg_images.sort()

# %%
bg_images
# Out:
# ['Cards/train/images\\0S1_jpg.rf.7dd27db352decb747371b094887e9721.jpg',
#  'Cards/train/images\\0S2_jpg.rf.9411b06096fbe459fdbec6d3bddf1f2f.jpg',
#  'Cards/train/images\\0S3_jpg.rf.75920bb0f0bd43ea59b56fa8fcfe13dc.jpg',
#  'Cards/train/images\\0S4_jpg.rf.6888b59a8f9e89b53f9ad133f38e0c6f.jpg',
#  'Cards/train/images\\20210914_133713_jpg.rf.d6e6eea493cf34952b3150153082769d.jpg',
#  'Cards/train/images\\20210914_133720_jpg.rf.c70d6eed248c487fc18cd48b11f68798.jpg',
#  'Cards/train/images\\20210914_133731_jpg.rf.72abe7d0ff653f99aa9ac7c00e389704.jpg',
#  'Cards/train/images\\20210914_133755_jpg.rf.6622514c103cfdc72c939df15d9b193a.jpg',
#  'Cards/train/images\\20210914_134235_jpg.rf.22b9a053c60d131aa817ee5637615661.jpg',
#  'Cards/train/images\\20210914_134242_jpg.rf.84ef6c6ff9217ee493455aa663446bca.jpg',
#  'Cards/train/images\\20210914_134248_jpg.rf.27b0bab33100f1578bb67774e0165cff.jpg',
#  'Cards/train/images\\20210914_134252_jpg.rf.792a8c003764990d843f34a7ab4cb74e.jpg',
#  'Cards/train/images\\20210914_134341_jpg.rf.6e262204882d2680d52ea8d3536763f2.jpg',
#  'Cards/train/images\\20210914_134348_jpg.rf.3b14c47252334994b7a17d636d31c05d.jpg',
#  'Cards/train/images\\20210914_134355_jpg.rf.127b2e4464906ae021594ba795f5f45b.jpg',
#  'Cards/train/images\\20210914_134401_jpg.rf.805d780895af42595d2d21aba69f2b22.jpg',
#  'Cards/train/images\\20210914_134438_jpg.rf.44e0f7cd4cde3a130cf2b85066e46415.jpg',
#  'Cards/train/images\\20210914_134446_jpg.rf.5571356c4fb18a4de97354f39b0e4d7d.jpg',
#  'Cards/train/images\\20210914_134456_jpg.rf.5ee92d2719f3e09807b8b9188e9b1454.jpg',
#  'Cards/train/images\\20210914_134503_jpg.rf.2256056ff8161109eab2d645ab667cc7.jpg',
#  'Cards/train/images\\20210914_134554_jpg.rf.bbcd301d5556a2f19788ba681b25931e.jpg',
#  'Cards/train/images\\20210914_134601_jpg.rf.2526926df50b011c2cd96314b4a6b2b8.jpg',
#  'Cards/train/images\\20210914_134609_jpg.rf.8cb26901671671195803cc0e9789ad40.jpg',
#  'Cards/train/images\\20210914_134614_jpg.rf.aa9b10c2b30496c7309ef7e60e7b9599.jpg',
#  'Cards/train/images\\20210914_134719_jpg.rf.72a43b0d5a059782d17d742c11f18218.jpg',
#  'Cards/train/images\\20210914_134724_jpg.rf.8e45460542a23c5f7a9d0ac80b8498bc.jpg',
#  'Cards/train/images\\20210914_134731_jpg.rf.574e0444c08c0ecc40b44cc1f141860d.jpg',
#  'Cards/train/images\\20210914_134738_jpg.rf.da0225a3268710f3376adff524324a02.jpg',
#  'Cards/train/images\\20210914_134831_jpg.rf.3e62532e54d3ef84b2caf723fa02831f.jpg',
#  'Cards/train/images\\20210914_134838_jpg.rf.22c62a1f3f3bb81a29a547249421d1ad.jpg',
#  'Cards/train/images\\20210914_134844_jpg.rf.3e3481bbd602c6c43a73490254feef2f.jpg',
#  'Cards/train/images\\20210914_134854_jpg.rf.d4e4d609a71c77db452aa8a1b944e599.jpg',
#  'Cards/train/images\\20210914_142501_jpg.rf.7aabcf39e8f6828d1ee9695738b7cce5.jpg',
#  'Cards/train/images\\20210914_142510_jpg.rf.a46017b7acd1dd58db9cb447e1697d7a.jpg',
#  'Cards/train/images\\20210914_142520_jpg.rf.95f7ab5d49ddd3f211337ed9dd0da9ba.jpg',
#  'Cards/train/images\\20210914_142539_jpg.rf.c6f28191827c9229accdff5a4d900d78.jpg',
#  'Cards/train/images\\20210914_142549_jpg.rf.11467e759c5dd88375309017bde2fe72.jpg',
#  'Cards/train/images\\20210914_142553_jpg.rf.36bae84d8b49e494d5b41e8811b44f12.jpg',
#  'Cards/train/images\\20210914_142559_jpg.rf.62f8f814c8f68dbf01ef70b6b07368f6.jpg',
#  'Cards/train/images\\20210914_142606_jpg.rf.c461b853d97e85a8764513d1675c4c73.jpg',
#  'Cards/train/images\\20210914_142614_jpg.rf.b15371ccf14b3bd690a5c68a106f147e.jpg',
#  'Cards/train/images\\20210914_142618_jpg.rf.9a386f049bae074775238532f9aa8ca6.jpg',
#  'Cards/train/images\\20210914_142623_jpg.rf.44dce088376185ab46d64236d2c1da1b.jpg',
#  'Cards/train/images\\20210914_142630_jpg.rf.aedcf5c0a36a61fd789a6ceadcc35ac0.jpg',
#  'Cards/train/images\\20210914_142640_jpg.rf.8792ab9878e6ae183675fb8d0eea7529.jpg',
#  'Cards/train/images\\20210914_142643_jpg.rf.de167c6214c74f0ce710234fd41c9021.jpg',
#  'Cards/train/images\\20210914_142652_jpg.rf.f58494b9b5d7466aadd8bcb364b33de6.jpg',
#  'Cards/train/images\\20210914_142658_jpg.rf.e24c4de0e5c190bece2092f49d830219.jpg',
#  'Cards/train/images\\20210914_142709_jpg.rf.fb8f20e085d01b971ae653e658b0c52f.jpg',
#  'Cards/train/images\\20210914_142713_jpg.rf.2dd9c231a2edbcfd547dab4a3a85e4cc.jpg',
#  'Cards/train/images\\20210914_142723_jpg.rf.5c11f09b8201ab0fc1adeb1518cdbb45.jpg',
#  'Cards/train/images\\20210914_142731_jpg.rf.54a12d9a388cf857b823eb36fa5843f7.jpg',
#  'Cards/train/images\\20210914_142739_jpg.rf.e74eae6bce391f452c13c0e9effa429f.jpg',
#  'Cards/train/images\\20210914_142745_jpg.rf.1870811a73cd95c9c1df56a97383f51a.jpg',
#  'Cards/train/images\\20210914_142749_jpg.rf.0a2ff8b5635bb7dc13cb41a6edf98dd9.jpg',
#  'Cards/train/images\\20210914_142757_jpg.rf.c16c6837307310806df718c230423637.jpg',
#  'Cards/train/images\\20210914_142809_jpg.rf.2732e886b0ddb75df398b0e6f1a44d43.jpg',
#  'Cards/train/images\\20210914_142817_jpg.rf.fc162a0848703a346ecc0fab8dc6efca.jpg',
#  'Cards/train/images\\20210914_142822_jpg.rf.321d57250d866eb6c876c236b2665059.jpg',
#  'Cards/train/images\\20210914_142827_jpg.rf.eb1f0a44f3d00b680415a2abe367b74e.jpg',
#  'Cards/train/images\\20210914_142835_jpg.rf.53ce4a035c589da4d36db4e9e21de686.jpg',
#  'Cards/train/images\\20210914_142839_jpg.rf.a2f137cff0742f7fdf9c3e6720c59132.jpg',
#  'Cards/train/images\\20210914_142844_jpg.rf.e726e93b8e255ff78ebfac3bd94899fe.jpg',
#  'Cards/train/images\\20210914_142849_jpg.rf.3ece55d6423077f3124f92a877fe7521.jpg',
#  'Cards/train/images\\20210914_142859_jpg.rf.1ce8f7eaabdd7e1e15e021fd5f3175a1.jpg',
#  'Cards/train/images\\20210914_142910_jpg.rf.f5affa227728b9179992b3860d5bd1cb.jpg',
#  'Cards/train/images\\20210914_142916_jpg.rf.4a61c23ea16d1578330a4222437b856c.jpg',
#  'Cards/train/images\\20210914_142922_jpg.rf.2a28db3c2ffdc7142768b2afdc961a5d.jpg',
#  'Cards/train/images\\20210914_142931_jpg.rf.d86411e38474155a6e548b2cf049d4ab.jpg',
#  'Cards/train/images\\20210914_142935_jpg.rf.ac78e3b1f776b5c9ea621a53fa8e9034.jpg',
#  'Cards/train/images\\20210914_142940_jpg.rf.1df554e0aa15e6293b15ec00cace57cf.jpg',
#  'Cards/train/images\\20210914_142948_jpg.rf.3b9ef45b742dcf5369f427562b6e9f06.jpg',
#  'Cards/train/images\\20210914_142954_jpg.rf.61dc983cbaf770e842f67f58f0e606c1.jpg',
#  'Cards/train/images\\20210914_142959_jpg.rf.a596bdece2cf23d6ac458ecd3fd901a6.jpg',
#  'Cards/train/images\\20210914_143004_jpg.rf.892a81c00c456e3eabf8b9a8774420ce.jpg',
#  'Cards/train/images\\20210914_143010_jpg.rf.ba16f536d8e8556106c2e5c6760c8f49.jpg',
#  'Cards/train/images\\20210914_143020_jpg.rf.c8e873a5d9ce76e9f03eeba6c59f9b6a.jpg',
#  'Cards/train/images\\20210914_143024_jpg.rf.43768170b47c12ff6ebf41cf6d55ffa6.jpg',
#  'Cards/train/images\\20210914_143030_jpg.rf.5c693e8e24a4b7b0cb7a55f421c537fa.jpg',
#  'Cards/train/images\\20210914_143036_jpg.rf.e209b2573e215a8deb459606c896f2d1.jpg',
#  'Cards/train/images\\20210914_143044_jpg.rf.9243a3fcfac912affaa094668850649a.jpg',
#  'Cards/train/images\\20210914_143048_jpg.rf.b1bffad2183e0d52b4b42455297aa9a0.jpg',
#  'Cards/train/images\\20210914_143053_jpg.rf.5b9bffd1baae2beb91070dd01c3f8298.jpg',
#  'Cards/train/images\\20210914_143057_jpg.rf.ab8898f387025ac20fcf5c60a15c08c5.jpg',
#  'Cards/train/images\\20210914_144239_jpg.rf.841a8b6c96de986231af697073e11891.jpg',
#  'Cards/train/images\\20210914_144243_jpg.rf.28d2b5c4224428c082df5bc7f18625b6.jpg',
#  'Cards/train/images\\20210914_144247_jpg.rf.b577281c604f863ee4e65a47b03a9e75.jpg',
#  'Cards/train/images\\20210914_144253_jpg.rf.6baa7f2b7014ff9fe5a30f5bbf818b91.jpg',
#  'Cards/train/images\\20210914_144300_jpg.rf.44b8445873e92433954ad5964578087d.jpg',
#  'Cards/train/images\\20210914_144304_jpg.rf.e4e16d3a68b797ac15aa8e4ae4b226fb.jpg',
#  'Cards/train/images\\20210914_144308_jpg.rf.d64948b41f25703585b6790ba1f81d3d.jpg',
#  'Cards/train/images\\20210914_144312_jpg.rf.570030213c17626a521c6dfc2a4f3a92.jpg',
#  'Cards/train/images\\20210914_144322_jpg.rf.d59b46198a2d7ec3a6c5d4f20c5438d1.jpg',
#  'Cards/train/images\\20210914_144327_jpg.rf.aa8178189def44b0ecebcb415f8d4e2d.jpg',
#  'Cards/train/images\\20210914_144332_jpg.rf.22b6a49a515d8d472e1f86ef4810a6b0.jpg',
#  'Cards/train/images\\20210914_144338_jpg.rf.8f6cad081186478d1fe62e6090fd05e0.jpg',
#  'Cards/train/images\\20210914_144404_jpg.rf.fdf003382ecb2b6f3de765e73228e313.jpg',
#  'Cards/train/images\\20210914_144409_jpg.rf.1a6a1c5801887383916e20d242dc12e3.jpg',
#  'Cards/train/images\\20210914_144416_jpg.rf.8ab62d0f6f7862ad953e81591d3a63c9.jpg',
#  'Cards/train/images\\20210914_144420_jpg.rf.58c9c5a0a1f128d82e2c0008fcef7ddf.jpg',
#  'Cards/train/images\\20210914_144430_jpg.rf.7ef52f6adecd41c72887f1bf3679dbd8.jpg',
#  'Cards/train/images\\20210914_144434_jpg.rf.634f39688ea2b6a08ba35099813e2834.jpg',
#  'Cards/train/images\\20210914_144444_jpg.rf.4e4b054921c2a23c013b6f9f205c54fb.jpg',
#  'Cards/train/images\\20210914_144450_jpg.rf.e54c63e58c480f07eb3721191de564bf.jpg',
#  'Cards/train/images\\20210914_144456_jpg.rf.4547fb11fc8bd1a9187630d2433f00c7.jpg',
#  'Cards/train/images\\20210914_144500_jpg.rf.ec08d0a320536e1d97c1f01b158ab031.jpg',
#  'Cards/train/images\\20210914_144506_jpg.rf.60dedec61240d5a44864e60d497cf68a.jpg',
#  'Cards/train/images\\20210914_144512_jpg.rf.27d51d4074d6bc22c5bb0cc287275e36.jpg',
#  'Cards/train/images\\20210914_144520_jpg.rf.26494fbb28943fa50db0a182788599a6.jpg',
#  'Cards/train/images\\20210914_144524_jpg.rf.d2869717741759adeb124a73e4e759f3.jpg',
#  'Cards/train/images\\20210914_144528_jpg.rf.da3230bb25ecd4fd7cb3f5b3b6387f79.jpg',
#  'Cards/train/images\\20210914_144535_jpg.rf.dcc03d6060bb212c6ab933f74ac87ee7.jpg',
#  'Cards/train/images\\20210914_144542_jpg.rf.25dd7d8fa37512a6c635ce24591b45d7.jpg',
#  'Cards/train/images\\20210914_144546_jpg.rf.c8c3e11597d471ba6a579d813736cbf6.jpg',
#  'Cards/train/images\\20210914_144550_jpg.rf.5406d6698e7ee5562a40a1e4b2989397.jpg',
#  'Cards/train/images\\20210914_144556_jpg.rf.6995c8e625bd0870b218b9702f1a49a5.jpg',
#  'Cards/train/images\\20210914_144603_jpg.rf.b0af77b397388d974a77ba80276e5bcb.jpg',
#  'Cards/train/images\\20210914_144607_jpg.rf.95618bbf9cd00d1e8a941c81155f1a84.jpg',
#  'Cards/train/images\\20210914_144611_jpg.rf.c138782520c077f3f58bea9f85f15b7f.jpg',
#  'Cards/train/images\\20210914_144616_jpg.rf.0e5b2b78487fbfa9735064411e85eae1.jpg',
#  'Cards/train/images\\20210914_144630_jpg.rf.92c4729c89a53ef98b40c92c3a1c6230.jpg',
#  'Cards/train/images\\20210914_144637_jpg.rf.befc92afe9ed87370b61a3012ffe19dd.jpg',
#  'Cards/train/images\\20210914_144644_jpg.rf.86f687ddf9f636de03ac64bd8593230a.jpg',
#  'Cards/train/images\\20210914_144650_jpg.rf.16cb1306570ce9204cd05db234971389.jpg',
#  'Cards/train/images\\20210914_144704_jpg.rf.b2f0f73aefda565c352676e943e66344.jpg',
#  'Cards/train/images\\20210914_144707_jpg.rf.483f74b63a6f4bfe18b0a86c3b2c66c7.jpg',
#  'Cards/train/images\\20210914_144713_jpg.rf.4b14ef10f7df7998c69df88e02c99f23.jpg',
#  'Cards/train/images\\20210914_144718_jpg.rf.e7fbf01c97970032ec16a8a51f44e16b.jpg',
#  'Cards/train/images\\20210914_144726_jpg.rf.fc03aa39766d382b7b94972812f21e17.jpg',
#  'Cards/train/images\\20210914_144730_jpg.rf.76262f5a5b34b81bab5880465120a705.jpg',
#  'Cards/train/images\\20210914_144745_jpg.rf.1800e1c0b3c75d55192966cba2d02cf7.jpg',
#  'Cards/train/images\\20210914_144753_jpg.rf.ce43ce470ddaf713cb7bffdf2e2d3a25.jpg',
#  'Cards/train/images\\20210914_144808_jpg.rf.50ae09419a97def469ee83ae306b72ea.jpg',
#  'Cards/train/images\\20210914_144813_jpg.rf.db5b9d7d369c616939da31685ed2cdf9.jpg',
#  'Cards/train/images\\20210914_144820_jpg.rf.eaac1f60f072975f43f8a849420ab115.jpg',
#  'Cards/train/images\\20210914_144825_jpg.rf.e26b0d75b886bbe9f273dba046ee0064.jpg',
#  'Cards/train/images\\20210914_150523_jpg.rf.a6e66cbc8cb0ddea497576c440ff0002.jpg',
#  'Cards/train/images\\20210914_150529_jpg.rf.4cf78a63209ca18900a2dc7ab9fc59b4.jpg',
#  'Cards/train/images\\20210914_150535_jpg.rf.57c71709f03aa60356c91d3398b1daed.jpg',
#  'Cards/train/images\\20210914_150543_jpg.rf.51728f11ac6f245187aa8bffd21b854e.jpg',
#  'Cards/train/images\\20210914_150552_jpg.rf.3ab3352cce4e1df9791ee5a5b31c1510.jpg',
#  'Cards/train/images\\20210914_150558_jpg.rf.cf081d4de50a46be6b97ba27d02286ac.jpg',
#  'Cards/train/images\\20210914_150604_jpg.rf.59f376c24e61e802d5aa79362c20e56a.jpg',
#  'Cards/train/images\\20210914_150610_jpg.rf.b23a5b3a9bb635f0db46a2b3708835fb.jpg',
#  'Cards/train/images\\20210914_150618_jpg.rf.c68a3b2692b1a9d7697c743cc7f52487.jpg',
#  'Cards/train/images\\20210914_150622_jpg.rf.c01bb3d80ba0389e31d4a0c28834ead3.jpg',
#  'Cards/train/images\\20210914_150626_jpg.rf.4edc89c77af5c1962259db66c9d63148.jpg',
#  'Cards/train/images\\20210914_150635_jpg.rf.ac10e728eedcb7f72f113ffb4f2aaaae.jpg',
#  'Cards/train/images\\20210914_150652_jpg.rf.56969059556bf327c1c5e74b23e72ec2.jpg',
#  'Cards/train/images\\20210914_150658_jpg.rf.83102552146afbe18203cd3b55d0e317.jpg',
#  'Cards/train/images\\20210914_150702_jpg.rf.d9347ac6c4b9d4f737cdbbcd84dcdb69.jpg',
#  'Cards/train/images\\20210914_150707_jpg.rf.f3fb36c031968e32e219bd45d2de8bed.jpg',
#  'Cards/train/images\\20210914_150716_jpg.rf.bff6f7475717c4437b4bc1f8c16c5b49.jpg',
#  'Cards/train/images\\20210914_150720_jpg.rf.e0a127e6c7340891c2eeed4d503bd605.jpg',
#  'Cards/train/images\\20210914_150727_jpg.rf.4f2ee9452586b9aa52fabbe9dda629f4.jpg',
#  'Cards/train/images\\20210914_150732_jpg.rf.ca67c56df8f2e5643500624e4f9b252f.jpg',
#  'Cards/train/images\\20210914_150740_jpg.rf.b729c1c29c4d46e011528c40a36a1ab3.jpg',
#  'Cards/train/images\\20210914_150744_jpg.rf.ce07b61798366cf670b64849f3c38512.jpg',
#  'Cards/train/images\\20210914_150749_jpg.rf.b50ce5c0599296a6e1fe0fe99430b598.jpg',
#  'Cards/train/images\\20210914_150806_jpg.rf.8dabba08f69f12c5b083fff12b338801.jpg',
#  'Cards/train/images\\20210914_150813_jpg.rf.1d937bda12a787c2b792712d2c92de34.jpg',
#  'Cards/train/images\\20210914_150821_jpg.rf.f961688a2032958e3db43ce61410b5a6.jpg',
#  'Cards/train/images\\20210914_150828_jpg.rf.8d9870fdd8fe384c0558fdcb22fd379b.jpg',
#  'Cards/train/images\\20210914_150833_jpg.rf.ec6c26f081455772abff2baab3c9526d.jpg',
#  'Cards/train/images\\20210914_150840_jpg.rf.0a398bf10f9dbe20da758c201c6f1f8e.jpg',
#  'Cards/train/images\\20210914_150846_jpg.rf.e930bbc0d4446a52f4128611cf6eb5fc.jpg',
#  'Cards/train/images\\20210914_150852_jpg.rf.187cd2d742d3de5314cfb30f71fff007.jpg',
#  'Cards/train/images\\20210914_150857_jpg.rf.ecbf1c0e3502c861f1094a0808cb474c.jpg',
#  'Cards/train/images\\20210914_150905_jpg.rf.4a3b70562d33844fea15729d36cd1084.jpg',
#  'Cards/train/images\\20210914_150910_jpg.rf.86be74d7bee331ea960c2f45dc5bf858.jpg',
#  'Cards/train/images\\20210914_150915_jpg.rf.1e7611969b04d1cacba33af11241aee2.jpg',
#  'Cards/train/images\\20210914_150921_jpg.rf.9596cb2385a6fee7970708b760b4b785.jpg',
#  'Cards/train/images\\20210914_150929_jpg.rf.aa32beadfd15823bc2eb6ba29bd51312.jpg',
#  'Cards/train/images\\20210914_150934_jpg.rf.46cfc4031b9fc8ecff3f9b558acb9a69.jpg',
#  'Cards/train/images\\20210914_150939_jpg.rf.d4167074d30b8647523fffaff34d9972.jpg',
#  'Cards/train/images\\20210914_150944_jpg.rf.68bc03774a124f61148ff506f7e2a1a9.jpg',
#  'Cards/train/images\\20210914_150952_jpg.rf.54f79a550190cf3eda092daf8bc27231.jpg',
#  'Cards/train/images\\20210914_150956_jpg.rf.731b01f0f2c2f78f26b75e6e78e9069e.jpg',
#  'Cards/train/images\\20210914_151003_jpg.rf.39f68bb75ece85d7007597de14267327.jpg',
#  'Cards/train/images\\20210914_151016_jpg.rf.fdbe629f972c27c93a2812526dd4a25e.jpg',
#  'Cards/train/images\\20210914_151024_jpg.rf.90b8b60317803bb3d6c399b756793c44.jpg',
#  'Cards/train/images\\20210914_151028_jpg.rf.c0085b39fa3b109f43dc815911fee8e0.jpg',
#  'Cards/train/images\\20210914_151035_jpg.rf.b82e9c721e16a941d789172a03a36700.jpg',
#  'Cards/train/images\\20210914_151044_jpg.rf.e13be86277ca03e15a393a03db3d897e.jpg',
#  'Cards/train/images\\20210914_151053_jpg.rf.0f4813d70196307730c52cf779197e7a.jpg',
#  'Cards/train/images\\20210914_151057_jpg.rf.a0544eb486d69730d8c9da717e8d2d9f.jpg',
#  'Cards/train/images\\20210914_151104_jpg.rf.2ba033de37d9bc1e28605638a8d02e61.jpg',
#  'Cards/train/images\\20210914_151110_jpg.rf.748ae764c0a1d14ac30fca2ef611f25e.jpg',
#  'Cards/train/images\\2S1_jpg.rf.7bada78e33c3eaa2f1d175a7adc60edd.jpg',
#  'Cards/train/images\\2S2_jpg.rf.82a498358c7deb714b897aeb758de892.jpg',
#  'Cards/train/images\\2S3_jpg.rf.a349a569558c023c2839615def1aaadf.jpg',
#  'Cards/train/images\\2S4_jpg.rf.cec2fe162fe98237ca6cee4583b69c5f.jpg',
#  'Cards/train/images\\4S1_jpg.rf.fde4ccf00c94616a467de3d1b76ffd9d.jpg',
#  'Cards/train/images\\4S2_jpg.rf.fd5490972299e98361934463e9d52243.jpg',
#  'Cards/train/images\\4S3_jpg.rf.3f4bea5e1c65a3fea22689cfc14fc782.jpg',
#  'Cards/train/images\\4S4_jpg.rf.649a6d8f20c536999a435ce0ffe4331e.jpg',
#  'Cards/train/images\\6S1_jpg.rf.45171d81b61f175210953a6ad598f9d7.jpg',
#  'Cards/train/images\\6S2_jpg.rf.4b400c40aecb47eb8f14211971f71f08.jpg',
#  'Cards/train/images\\6S3_jpg.rf.73ea8ba99fbbbba634c07e04fba17142.jpg',
#  'Cards/train/images\\6S4_jpg.rf.c305151937818c194b348451776e2e00.jpg',
#  'Cards/train/images\\8S1_jpg.rf.00012aa90eba6211209392b52d9f49b1.jpg',
#  'Cards/train/images\\8S2_jpg.rf.82f201058ce55848644033df307e1024.jpg',
#  'Cards/train/images\\8S3_jpg.rf.b4124b19f8b3ba55b821694084c0c629.jpg',
#  'Cards/train/images\\8S4_jpg.rf.dbf629eae26e5e0fa414f2608d0b4e22.jpg',
#  'Cards/train/images\\QS1_jpg.rf.5aa4a61053d8361aaa9f0364039f9836.jpg',
#  'Cards/train/images\\QS2_jpg.rf.15bf9b863e14e66993151d248aac41d1.jpg',
#  'Cards/train/images\\QS3_jpg.rf.f4b8cd86473eedbdb987d52b90922092.jpg',
#  'Cards/train/images\\QS4_jpg.rf.dde1da55956e1bff18d0aa2d7589b968.jpg']
